# %%
import GEOparse

# %%
gse = GEOparse.get_GEO(filepath="./GSE107011_family.soft.gz")
# Out:
# 04-Jul-2019 16:15:27 INFO GEOparse - Parsing ./GSE107011_family.soft.gz:
# 04-Jul-2019 16:15:27 DEBUG GEOparse - DATABASE: GeoMiame
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SERIES: GSE107011
# 04-Jul-2019 16:15:27 DEBUG GEOparse - PLATFORM: GPL11154
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859411
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859412
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859413
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859414
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859415
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859416
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859417
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859418
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859419
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859420
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859421
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859422
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859423
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859424
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859425
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859426
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859427
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859428
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859429
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859430
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859431
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859432
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859433
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859434
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859435
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859436
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859437
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859438
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859439
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859440
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859441
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859442
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859443
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859444
# 04-Jul-2019 16:15:27 DEBUG GEOparse - SAMPLE: GSM2859445
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859446
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859447
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859448
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859449
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859450
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859451
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859452
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859453
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859454
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859455
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859456
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859457
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859458
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859459
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859460
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859461
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859462
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859463
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859464
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859465
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859466
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859467
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859468
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859469
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859470
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859471
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859472
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859473
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859474
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859475
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859476
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859477
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859478
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859479
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859480
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859481
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859482
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859483
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859484
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859485
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859486
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859487
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859488
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859489
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859490
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859491
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859492
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859493
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859494
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859495
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859496
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859497
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859498
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859499
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859500
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859501
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859502
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859503
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859504
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859505
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859506
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859507
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859508
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859509
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859510
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859511
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859512
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859513
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859514
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859515
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859516
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859517
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859518
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859519
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859520
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859521
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859522
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859523
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859524
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859525
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859526
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859527
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859528
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859529
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859530
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859531
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859532
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859533
# 04-Jul-2019 16:15:28 DEBUG GEOparse - SAMPLE: GSM2859534
# 04-Jul-2019 16:15:29 DEBUG GEOparse - SAMPLE: GSM2859535
# 04-Jul-2019 16:15:29 DEBUG GEOparse - SAMPLE: GSM2859536
# 04-Jul-2019 16:15:29 DEBUG GEOparse - SAMPLE: GSM2859537

# %%
print()
print("GSM example:")
for gsm_name, gsm in gse.gsms.items():
    print("Name: ", gsm_name)
    print("Metadata:",)
    for key, value in gsm.metadata.items():
        print(" - %s : %s" % (key, ", ".join(value)))
    print ("Table data:",)
    print (gsm.table.head())
    break
# Out:
# GSM example:
# Name:  GSM2859411
# Metadata:
#  - title : DZQV_CD8_naive_rep4
#  - geo_accession : GSM2859411
#  - status : Public on Feb 06 2019
#  - submission_date : Nov 16 2017
#  - last_update_date : May 15 2019
#  - type : SRA
#  - channel_count : 1
#  - source_name_ch1 : Naive CD8 T cells
#  - organism_ch1 : Homo sapiens
#  - taxid_ch1 : 9606
#  - characteristics_ch1 : cell type: Naive CD8 T cells, disease status: healthy, gender: M
#  - molecule_ch1 : polyA RNA
#  - extract_protocol_ch1 : RNA was extracted with TRIzol reagent, followed by clean-up and DNase I treatment with QIAGEN RNeasy mini kit in accordance with the prescribed protocol provided with the kit. Quality control was performed with Agilent Bioanalyser. The RNA concentration was determined using the Quant-iTTM RiboGreen® RNA Assay Kit, The cDNA libraries were prepared from 2 ng of total RNA and 1 μl of a 1:50,000 dilution of external RNA control consortium (ERCC) spike-in control mix (Thermo Fisher Scientific) using SMARTSeq v2 protocol (Picelli et al., 2014) with the following modifications: 1) use of 20µM template-switching oligos (TSO), 2) use of 250 pg of cDNA with 1/5 reaction mixtures of Illumina Nextera XT kit.
#  - description : cell_number (facs): 900000, total_rna_yield (ng): 321.78, DZQV_CD8_naive
#  - data_processing : Sequenced reads were trimmed for adaptor sequence, and masked for low-complexity or low-quality sequence, then mapped to the transcriptome with kallisto, Transcirpt per million (TPM) values of all trancripts were obtained with kallisto. Expression counts at gene level were obtained by summarizing transcript expression values., Genome_build: GENCODE 26, Supplementary_files_format_and_content: tab-delimited text files include TPM values for each sample
#  - platform_id : GPL11154
#  - contact_name : Gianni,,Monaco
#  - contact_email : mongianni1@gmail.com
#  - contact_institute : University of Liverpool
#  - contact_address : 6 West Derby Street
#  - contact_city : Liverpool
#  - contact_zip/postal_code : L78TX
#  - contact_country : United Kingdom
#  - instrument_model : Illumina HiSeq 2000
#  - library_selection : cDNA
#  - library_source : transcriptomic
#  - library_strategy : RNA-Seq
#  - relation : BioSample: https://www.ncbi.nlm.nih.gov/biosample/SAMN08035215, SRA: https://www.ncbi.nlm.nih.gov/sra?term=SRX3399186
#  - supplementary_file_1 : NONE
#  - series_id : GSE107011, GSE107019
#  - data_row_count : 0
# Table data:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print()
print("GPL example:")
for gpl_name, gpl in gse.gpls.items():
    print("Name: ", gpl_name) 
    print("Metadata:",)
    for key, value in gpl.metadata.items():
        print(" - %s : %s" % (key, ", ".join(value))) 
    print("Table data:",)
    print(gpl.table.head())
    break
# Out:
# GPL example:
# Name:  GPL11154
# Metadata:
#  - title : Illumina HiSeq 2000 (Homo sapiens)
#  - geo_accession : GPL11154
#  - status : Public on Nov 02 2010
#  - submission_date : Nov 02 2010
#  - last_update_date : Mar 27 2019
#  - technology : high-throughput sequencing
#  - distribution : virtual
#  - organism : Homo sapiens
#  - taxid : 9606
#  - contact_name : ,,GEO
#  - contact_country : USA
#  - data_row_count : 0
# Table data:
# Empty DataFrame
# Columns: []
# Index: []
